# %% [markdown]
# <div style='font-size:14px'>this is same excercise but with month of year

# %%
import matplotlib.pyplot as plt
import pandas as pd
from datasets import load_dataset
import numpy as np
import ast

# Loading Data set
dataset= load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# cleanup
df['job_posted_date']=pd.to_datetime(df['job_posted_date'])
df['job_skills']=df['job_skills'].apply(lambda x: ast.literal_eval(x) if pd.notna(x) else x)

# %%
df_DA = df[df['job_title_short'] == 'Data Analyst'].copy()

# %%
df_DA

# %%
df_DA['job_posted_month']=df_DA['job_posted_date'].dt.strftime('%B')
df_DA
# Out:
#        job_title_short                                          job_title  \
# 1         Data Analyst                                       Data Analyst
# 12        Data Analyst        Stagiaire Data Analyst (H/F) - Lyon (69006)
# 18        Data Analyst                                       Data Analyst
# 31        Data Analyst                           Stage - Data Analyst F/H
# 34        Data Analyst  Data Analyst als Marketing Manager Automation ...
# ...                ...                                                ...
# 785703    Data Analyst            Data Analyst - CRYPTOGRAPHY - Full-time
# 785705    Data Analyst          Expert Business Data Analyst - Now Hiring
# 785715    Data Analyst  Amul Careers 2023 - Apply Online - Data Analys...
# 785717    Data Analyst                 Data & Analytics Architect (w/m/x)
# 785737    Data Analyst                                   CRM Data Analyst
#
#                         job_location  \
# 1       Guadalajara, Jalisco, Mexico
# ...

# %%
df_DA_explode = df_DA.explode('job_skills')

df_DA_explode

# %%
df_DA_pivot = df_DA_explode.pivot_table(
    index='job_posted_month',
    columns='job_skills',
    aggfunc='size'
)

# %%
df_DA_pivot.reset_index(inplace=True)

# %%
df_DA_pivot['month_no']=pd.to_datetime(df_DA_pivot['job_posted_month'], format='%B').dt.month

df_DA_pivot['month_no']
# Out:
# 0      4
# 1      8
# 2     12
# 3      2
# 4      1
# 5      7
# 6      6
# 7      3
# 8      5
# 9     11
# 10    10
# 11     9
# Name: month_no, dtype: int32

# %%
df_DA_pivot.sort_values('month_no',inplace= True)
df_DA_pivot.set_index('job_posted_month',inplace=True)

# %%
df_DA_pivot.loc['total']=df_DA_pivot.sum()

# %%
df_DA_pivot=df_DA_pivot[df_DA_pivot.loc['total'].sort_values(ascending=False).index]

# %%
df_DA_pivot.drop(index='total',inplace=True)

# %%
df_DA_pivot.iloc[:,:5].plot(kind='line')
plt.title('Top 5 Skills for Data Analysts per Month')
plt.ylabel('Count')
plt.xlabel('')
plt.show()
