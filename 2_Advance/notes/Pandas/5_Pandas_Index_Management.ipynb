# %% [markdown]
# ###### Index Management:
# <div style='font-size:14px'> when we do operations on our data frames to manipulate it, it kind of jacks up our index and so we need to know certain methods in order to fix back our index

# %%
import matplotlib.pyplot as plt
import pandas as pd
from datasets import load_dataset
import numpy as np

# Loading Data set
dataset= load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# cleanup
df['job_posted_date']=pd.to_datetime(df['job_posted_date'])

# %%
df.index
# Out:
# RangeIndex(start=0, stop=785741, step=1)

# %% [markdown]
# <div style='font-size:14px'>when we run df  here we will see that index column does not holds any name to assign it a name .index.name is used

# %%
df.index.name = 'job_index'
df.head()
# Out:
#                 job_title_short  \
# job_index
# 0          Senior Data Engineer
# 1                  Data Analyst
# 2                 Data Engineer
# 3                 Data Engineer
# 4                 Data Engineer
#
#                                                    job_title  \
# job_index
# 0          Senior Clinical Data Engineer / Principal Clin...
# 1                                               Data Analyst
# 2          Data Engineer/Scientist/Analyst, Mid or Senior...
# 3          LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                     Data Engineer- Sr Jobs
#
#                            job_location             job_via job_schedule_type  \
# job_index
# 0                         Watertown, CT     via Work Nearby         Full-time
# 1          Guadalajara, Jalisco, Mexico    via BeBee México         Full-time
# 2                       Berlin, Germany        via LinkedIn         Full-time
# ...

# %%
df.index.dtype
# Out:
# dtype('int64')

# %% [markdown]
# ###### Reset Index()
# <div style='font-size:14px'> lets say i want to create new df that it's filtered for jobs particular to US so the query will give result with irregular indexes, so using .reset_index will reset their index and make them regular. Now there's a host of different parameters we can use but we will focus only on inplace : whether to modify DataFrame rather than creating a new one.okk as we saw this doesn't replace the pre-existing index but give the df a bnew indexing, after this indexing we can drop the earlier irregular indexes but what if in fututre we learn about smthng like merge df and I want to use an index to merge it back i can then use that in that case so we will keep it for that time being.

# %%
df_india = df[df['job_country'] == 'India']

df_india.reset_index(inplace= True)
df_india
# Out:
#        job_index       job_title_short  \
# 0             16         Data Engineer
# 1             19        Data Scientist
# 2             29        Data Scientist
# 3             38          Data Analyst
# 4             42  Senior Data Engineer
# ...          ...                   ...
# 51083     785712         Data Engineer
# 51084     785715          Data Analyst
# 51085     785716     Software Engineer
# 51086     785718      Business Analyst
# 51087     785740     Software Engineer
#
#                                                job_title  \
# 0                                      Big Data Engineer
# 1                                         Data Scientist
# 2                                         Data Scientist
# 3                  Data Quality and Governance Analyst 1
# 4            Senior Data Engineer(Python)-1563,1637&1633
# ...                                                  ...
# 51083                     India - Collections Analyst II
# ...

# %% [markdown]
# <div style='font-size:14px'>next method is .set_index..set_index() is used to choose one (or more) column(s) of a DataFrame and make it the row index.
# In simple words:
# It turns a normal column into the left-side label (index) of the table.
# It sets the df index using an existing column

# %%
df_India.set_index('job_index', inplace=True)

df_India
# Out:
#                 job_title_short  \
# job_index
# 16                Data Engineer
# 19               Data Scientist
# 29               Data Scientist
# 38                 Data Analyst
# 42         Senior Data Engineer
# ...                         ...
# 785712            Data Engineer
# 785715             Data Analyst
# 785716        Software Engineer
# 785718         Business Analyst
# 785740        Software Engineer
#
#                                                    job_title  \
# job_index
# 16                                         Big Data Engineer
# 19                                            Data Scientist
# 29                                            Data Scientist
# 38                     Data Quality and Governance Analyst 1
# 42               Senior Data Engineer(Python)-1563,1637&1633
# ...                                                      ...
# 785712                        India - Collections Analyst II
# ...

# %% [markdown]
# <div style='font-size:14px'>the last method to use is .sort_index..sort_index() sorts a DataFrame (or Series) based on its INDEX, not on column values.
# Simple line:
# It rearranges rows according to the order of the index.
# It returns a df sorted by label.
# sort_index or sort_value mai difference ye hai ki .sort_index() sorts by Index and .sort_values() sorts by Column values

# %%
df_india.sort_index(inplace= True)
df_india
# Out:
#                 job_title_short  \
# job_index
# 16                Data Engineer
# 19               Data Scientist
# 29               Data Scientist
# 38                 Data Analyst
# 42         Senior Data Engineer
# ...                         ...
# 785712            Data Engineer
# 785715             Data Analyst
# 785716        Software Engineer
# 785718         Business Analyst
# 785740        Software Engineer
#
#                                                    job_title  \
# job_index
# 16                                         Big Data Engineer
# 19                                            Data Scientist
# 29                                            Data Scientist
# 38                     Data Quality and Governance Analyst 1
# 42               Senior Data Engineer(Python)-1563,1637&1633
# ...                                                      ...
# 785712                        India - Collections Analyst II
# ...
