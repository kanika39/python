# %% [markdown]
# ##### Box Plots
# <div style='font-size:14px'>Grt at comparing values specifically we could look at something like the distribution of salaries across DA,DE,DS. we covered histogram first is because box plots really build on that they both show distributions of numerical values.

# %%
import matplotlib.pyplot as plt
import pandas as pd
from datasets import load_dataset
import numpy as np
import ast

# Loading Data set
dataset= load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# cleanup
df['job_posted_date']=pd.to_datetime(df['job_posted_date'])
df['job_skills']=df['job_skills'].apply(lambda x: ast.literal_eval(x) if pd.notna(x) else x)

# %%
df_DA_India = df[(df['job_title_short']=='Data Analyst') & (df['job_country']=='India')]

df_DA_India=df_DA_India.dropna(subset='salary_year_avg')

# %% [markdown]
# # DOUBT
